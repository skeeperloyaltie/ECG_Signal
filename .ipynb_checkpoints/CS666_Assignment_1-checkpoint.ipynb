# %% [markdown]
# ![logo.png](data:image/png;base64,...)
#
# # Assignment 1

# %%
# %pylab inline
# Out:
# Matplotlib is building the font cache; this may take a moment.
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# **Task 1** (10pts): Install the BioSPPY library with the following code.

# %%
# !pip install biosppy
# Out:
# Collecting biosppy
#   Downloading biosppy-1.0.0-py2.py3-none-any.whl (106 kB)
#      ------------------------------------ 107.0/107.0 kB 887.6 kB/s eta 0:00:00
# Requirement already satisfied: scipy in c:\users\fr34k\anaconda3\ana\lib\site-packages (from biosppy) (1.9.1)
# Requirement already satisfied: six in c:\users\fr34k\appdata\roaming\python\python39\site-packages (from biosppy) (1.16.0)
# Requirement already satisfied: numpy in c:\users\fr34k\anaconda3\ana\lib\site-packages (from biosppy) (1.21.5)
# Requirement already satisfied: scikit-learn in c:\users\fr34k\anaconda3\ana\lib\site-packages (from biosppy) (1.0.2)
# Collecting shortuuid
#   Downloading shortuuid-1.0.11-py3-none-any.whl (10 kB)
# Requirement already satisfied: joblib in c:\users\fr34k\anaconda3\ana\lib\site-packages (from biosppy) (1.1.0)
# Collecting opencv-python
#   Downloading opencv_python-4.7.0.68-cp37-abi3-win_amd64.whl (38.2 MB)
#      ---------------------------------------- 38.2/38.2 MB 1.2 MB/s eta 0:00:00
# Collecting bidict
#   Downloading bidict-0.22.1-py3-none-any.whl (35 kB)
# Requirement already satisfied: matplotlib in c:\users\fr34k\anaconda3\ana\lib\site-packages (from biosppy) (3.5.2)
# Requirement already satisfied: h5py in c:\users\fr34k\anaconda3\ana\lib\site-packages (from biosppy) (3.7.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\fr34k\anaconda3\ana\lib\site-packages (from matplotlib->biosppy) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\fr34k\appdata\roaming\python\python39\site-packages (from matplotlib->biosppy) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\fr34k\anaconda3\ana\lib\site-packages (from matplotlib->biosppy) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\fr34k\anaconda3\ana\lib\site-packages (from matplotlib->biosppy) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\fr34k\anaconda3\ana\lib\site-packages (from matplotlib->biosppy) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\fr34k\anaconda3\ana\lib\site-packages (from matplotlib->biosppy) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\fr34k\appdata\roaming\python\python39\site-packages (from matplotlib->biosppy) (23.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\fr34k\anaconda3\ana\lib\site-packages (from scikit-learn->biosppy) (2.2.0)
# Installing collected packages: shortuuid, opencv-python, bidict, biosppy
# Successfully installed bidict-0.22.1 biosppy-1.0.0 opencv-python-4.7.0.68 shortuuid-1.0.11

# %% [markdown]
# **Task 2** (10 pts): Download a sample ecg dataset from https://cs666.org/data/ecg.txt and upload it to this colab. The following code loads the dataset.

# %%
from biosppy import storage
signal, metadata = storage.load_txt('ecg.txt')

# %% [markdown]
# **Task 3** (10 pts): Figure out the sampling rate for this data and how many seconds it lasts.

# %%
num_samples = signal.shape[0]

# %%
num_samples

# %%
SAMPLING_RATE = 1000
SECONDS = num_samples / SAMPLING_RATE

# %% [markdown]
# **Task 4** (20 pts): Process the signal with BioSPPY using the `ecg.ecg` method.

# %%
### TODO
from biosppy.signals import ecg
import matplotlib.pyplot as plt


# Process the ECG signal
ecgOut = ecg.ecg(signal=signal, sampling_rate=1000., show=False)

# Extract the QRS complex locations
qrs_locs = ecgOut['rpeaks']

# %% [markdown]
# **Task 5** (10 pts): Plot the first 3 seconds of the unfiltered signal and then the filtered signal. Can you spot the P, Q, R, S, T waves?

# %%
num_samples = int(3 * metadata['sampling_rate'])

# Plot the first 3 seconds of the unfiltered and filtered signals
plt.figure(figsize=(10, 5))
plt.plot(signal[:num_samples], label='Unfiltered')
plt.plot(ecgOut['filtered'][:num_samples], label='Filtered')
plt.xlabel('Sample Index')
plt.ylabel('Amplitude')
plt.title('First 3 seconds of ECG signal')
plt.legend()
plt.show()

# %%
### TODO plot filtered signal

# Plot the first 3 seconds of the unfiltered and filtered signals
plt.figure(figsize=(10, 5))
# plt.plot(signal[:num_samples], label='Unfiltered')
plt.plot(ecgOut['filtered'][:num_samples], label='Filtered')
plt.xlabel('Sample Index')
plt.ylabel('Amplitude')
plt.title('First 3 seconds of ECG signal')
plt.legend()
plt.show()

# %% [markdown]
# **Task 6** (15 pts): Please plot the whole filtered signal and mark the r-peaks with vertical lines based on the ecg.ecg output. You can use `plt.axvline(x = 100, color = 'r', ls=':')` to create a red, dashed vertical line at position 100. Please label the x-axis as 'time [s]'.

# %%
### TODO
import numpy as np
# Plot the filtered ECG signal
plt.figure(figsize=(10, 5))
plt.plot(ecgOut['filtered'], label='Filtered')
plt.xlabel('Sample Index')
plt.ylabel('Amplitude')
plt.title('Filtered ECG signal')

# Mark the R-peaks with vertical lines
for loc in qrs_locs:
    plt.axvline(x=loc, color='red', ls=':')

# Convert the sample index to time in seconds
time = np.linspace(0, len(signal) / metadata['sampling_rate'], len(signal))
plt.xlim([0, time[-1]])
plt.xticks(np.arange(0, time[-1], 1))
plt.xlabel('Time [s]')

plt.show()

# %% [markdown]
# **Task 7** (5 pts): Let's install the NeuroKit2 library.

# %%
# !pip install neurokit2
import neurokit2 as nk

# %% [markdown]
# **Task 8** (20 pts): Detect P Q S T Peaks using Neurokit.

# %%
# We know the R spikes now but what about P Q S T waves?
# TODO Can you use nk.ecg_delineate to detect them in the unfiltred signal?
# Hint: Look at the tutorial: https://neuropsychology.github.io/NeuroKit/examples/ecg_delineate/ecg_delineate.html
# Hint 2: The plot will have blue, orange, green, and red circles :)
# Hint 3: rpeaks were detected above from biosppy's ecg.ecg method
import neurokit2 as nk
rpeaks = ecgOut['rpeaks']

# Delineate the ECG signal
delineation = nk.ecg_delineate(signal, sampling_rate=metadata['sampling_rate'], rpeaks=rpeaks)

P_peaks = delineation[0]
P_onsets = delineation[1]
P_offsets = delineation[2]
Q_peaks = delineation[3]
R_onsets = delineation["ECG_R_Onsets"]
R_offsets = delineation["ECG_R_Offsets"]
S_peaks = delineation["ECG_S_Peaks"]
T_peaks = delineation["ECG_T_Peaks"]
T_onsets = delineation["ECG_T_Onsets"]
T_offsets = delineation["ECG_T_Offsets"]

delineation

# %%
# TODO Does the detection work well?

# %% [markdown]
# **Bonus Task** (33 pts): Detect P Q S T Peaks for the full signal before and after filtering.

# %%
# TODO As above use the nk.ecg_delineate function to detect peaks for the whole signal

# %%
# TODO Let's filter the signal and see if the detection improves.
# Hint: You can use nk.signal_filter to define a bandpass. 
# Hint 2: Which lowcut and highcut frequencies work well? Play with it :)
# Hint 3: You don't need to re-calculate the rpeaks since they are pretty accurate in general.

# %%
# Finally, run the delineation on the filtered signal from BioSPPY.

# %%
# TODO Which one works the best?

# %%
#
# Great job!!
#
#  , ; ,   .-'"""'-.   , ; ,
#  \\|/  .'         '.  \|//
#   \-;-/   ()   ()   \-;-/
#   // ;               ; \\
#  //__; :.         .; ;__\\
# `-----\'.'-.....-'.'/-----'
#        '.'.-.-,_.'.'
#jgs       '(  (..-'
#            '-'
#
